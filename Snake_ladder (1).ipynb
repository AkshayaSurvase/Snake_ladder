# %% [markdown]
# ###### import random
# import time
#
# # 1. SETUP: Define where the snakes and ladders are
# # Dict format: {start_position: end_position}
# LADDERS = {3: 38, 24: 33, 42: 93, 72: 84}
# SNAKES = {17: 7, 54: 34, 62: 19, 98: 79}
#
# def play_game():
#     positions = [0, 0]  # Player 1 is index 0, Player 2 is index 1
#     turn = 0            # Start with Player 1
#
#     print("Welcome to Snakes & Ladders!")
#     print("Goal: Reach 100 first. Press Enter to roll.")
#
#     while True:
#         player_num = turn + 1
#         input(f"\n--- Player {player_num}'s Turn ---")
#
#         # 2. THE ROLL
#         dice = random.randint(1, 6)
#         print(f"You rolled a {dice}!")
#
#         # 3. THE MOVE
#         new_pos = positions[turn] + dice
#
#         if new_pos > 100:
#             print(f"Stay put! You need exactly {100 - positions[turn]} to win.")
#             new_pos = positions[turn]
#         else:
#             # 4. CHECK FOR SNAKES/LADDERS
#             if new_pos in LADDERS:
#                 print(f"UP! Found a ladder at {new_pos}. Climbing to {LADDERS[new_pos]}.")
#                 new_pos = LADDERS[new_pos]
#             elif new_pos in SNAKES:
#                 print(f"OUCH! Bit by a snake at {new_pos}. Sliding down to {SNAKES[new_pos]}.")
#                 new_pos = SNAKES[new_pos]
#
#             positions[turn] = new_pos
#             print(f"Player {player_num} is now at square {positions[turn]}")
#
#         # 5. WIN CONDITION
#         if positions[turn] == 100:
#             print(f"\n🏆 CONGRATULATIONS! Player {player_num} wins!")
#             break
# 7
# 7
#
#         # 6. SWITCH TURNS
#         turn = 1 - turn  # Toggles between 0 and 1
#
# if __name__ == "__main__":
#     play_game()

# %%
import random
import time

# 1. SETUP: Define where the snakes and ladders are
# Dict format: {start_position: end_position}
LADDERS = {3: 38, 24: 33, 42: 93, 72: 84}
SNAKES = {17: 7, 54: 34, 62: 19, 98: 79}

def play_game():
    positions = [0, 0]  # Player 1 is index 0, Player 2 is index 1
    turn = 0            # Start with Player 1
    
    print("Welcome to Snakes & Ladders!")
    print("Goal: Reach 100 first. Press Enter to roll.")

    while True:
        player_num = turn + 1
        input(f"\n--- Player {player_num}'s Turn ---")
        
        # 2. THE ROLL
        dice = random.randint(1, 6)
        print(f"You rolled a {dice}!")
        
        # 3. THE MOVE
        new_pos = positions[turn] + dice
        
        if new_pos > 100:
            print(f"Stay put! You need exactly {100 - positions[turn]} to win.")
            new_pos = positions[turn]
        else:
            # 4. CHECK FOR SNAKES/LADDERS
            if new_pos in LADDERS:
                print(f"UP! Found a ladder at {new_pos}. Climbing to {LADDERS[new_pos]}.")
                new_pos = LADDERS[new_pos]
            elif new_pos in SNAKES:
                print(f"OUCH! Bit by a snake at {new_pos}. Sliding down to {SNAKES[new_pos]}.")
                new_pos = SNAKES[new_pos]
            
            positions[turn] = new_pos
            print(f"Player {player_num} is now at square {positions[turn]}")

        # 5. WIN CONDITION
        if positions[turn] == 100:
            print(f"\n🏆 CONGRATULATIONS! Player {player_num} wins!")
            break

        # 6. SWITCH TURNS
        turn = 1 - turn  # Toggles between 0 and 1

if __name__ == "__main__":
    play_game()
# Out:
# Welcome to Snakes & Ladders!
# Goal: Reach 100 first. Press Enter to roll.
# --- Player 1's Turn --- 5
# You rolled a 3!
# UP! Found a ladder at 3. Climbing to 38.
# Player 1 is now at square 38
# --- Player 2's Turn --- 5
# You rolled a 2!
# Player 2 is now at square 2
# --- Player 1's Turn --- 6
# You rolled a 3!
# Player 1 is now at square 41
# --- Player 2's Turn --- 6
# You rolled a 6!
# Player 2 is now at square 8
# --- Player 1's Turn --- 6
# You rolled a 5!
# Player 1 is now at square 46
# --- Player 2's Turn --- 6
# You rolled a 4!
# Player 2 is now at square 12
# --- Player 1's Turn --- 6
# You rolled a 1!
# Player 1 is now at square 47
# --- Player 2's Turn --- 6
# You rolled a 5!
# OUCH! Bit by a snake at 17. Sliding down to 7.
# Player 2 is now at square 7
# --- Player 1's Turn --- 6
# You rolled a 6!
# Player 1 is now at square 53
# --- Player 2's Turn --- 6
# You rolled a 5!
# Player 2 is now at square 12
# --- Player 1's Turn --- 6
# You rolled a 4!
# ...
